# %%
import requests
import pandas as pd
import re
from bs4 import BeautifulSoup as BS

# %%
URL = 'https://www.billboard.com/charts/hot-100/'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64'}


response = requests.get(URL, headers = headers)

# %%
soup = BS(response.text)

# %%
print(soup.prettify())
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
soup.find('h2').text
# Out:
# '\n\n\t\n\t\tWeek of November 29, 2025\n\t\n\t'

# %%
titles = soup.findAll('h3')
titles
# Out:
# [<h3 class="charts-nav-item-heading lrv-u-flex lrv-u-align-items-center lrv-u-color-white u-padding-r-13" id="charts-menu-item-top-charts">
#  <a class="c-link lrv-a-unstyle-link a-font-basic-fancy-xs u-letter-spacing-0028 u-font-size-14 u-font-size-18@mobile-max u-min-width-65p u-padding-l-13 u-padding-tb-10 u-padding-l-20@mobile-max lrv-u-color-white lrv-u-color-black:hover u-link-decoration-underline:hover" href="/charts/genre/top-charts/">
#  	Top Charts</a>
#  <button aria-label="charts-menu-expand" class="lrv-a-unstyle-button u-display-inline-flex lrv-u-margin-l-auto lrv-u-padding-l-050 u-padding-tb-10 lrv-a-icon-after a-icon-arrow-chart-nav-down" data-collapsible-toggle="always-show">
#  <span>
#  <span class="lrv-a-screen-reader-only">
#  					Expand top-charts menu				</span>
#  </span>
#  </button>
#  </h3>,
#  <h3 class="charts-nav-item-heading lrv-u-flex lrv-u-align-items-center lrv-u-color-white u-padding-r-13" id="charts-menu-item-global">
# ...

# %%
peak = soup.findAll('li', attrs={'class' : "o-chart-results-list__item // a-chart-bg-color a-chart-color lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center u-hidden@mobile-max"})

# %%
peak
# Out:
# [<li class="o-chart-results-list__item // a-chart-bg-color a-chart-color lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center u-hidden@mobile-max">
#  <span class="c-label u-font-family-secondary@mobile-max u-font-family-basic@tablet u-font-weight-800@tablet u-font-size-12 u-line-height-normal lrv-u-padding-tb-00@mobile-max u-min-width-30px u-width-auto@mobile-max u-min-width-auto@mobile-max lrv-u-margin-r-050@mobile-max">
#
#  	1
#  </span>
#  </li>,
#  <li class="o-chart-results-list__item // a-chart-bg-color a-chart-color lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center u-hidden@mobile-max">
#  <span class="c-label u-font-family-secondary@mobile-max u-font-family-basic@tablet u-font-weight-800@tablet u-font-size-12 u-line-height-normal lrv-u-padding-tb-00@mobile-max u-min-width-30px u-width-auto@mobile-max u-min-width-auto@mobile-max lrv-u-margin-r-050@mobile-max">
#
#  	1
#  </span>
#  </li>,
# ...

# %%
peak_clean = [item.text.strip() for item in peak]
peak_clean
# Out:
# ['1',
#  '1',
#  '1',
#  '4',
#  '2',
#  '6',
#  '2',
#  '1',
#  '7',
#  '7',
#  '3',
#  '10',
#  '1',
#  '3',
#  '1',
#  '16',
#  '16',
#  '18',
#  '5',
#  '1',
#  '3',
#  '3',
#  '5',
#  '4',
#  '12',
#  '3',
#  '9',
#  '3',
#  '9',
#  '5',
#  '31',
#  '12',
#  '33',
#  '7',
#  '35',
#  '8',
#  '8',
#  '30',
#  '39',
#  '4',
#  '36',
#  '15',
#  '28',
#  '6',
#  '40',
#  '4',
#  '47',
#  '15',
#  '6',
#  '20',
#  '35',
#  '17',
#  '30',
#  '45',
#  '55',
#  '54',
#  '47',
#  '58',
#  '52',
#  '60',
#  '43',
#  '62',
#  '50',
#  '8',
#  '22',
#  '43',
#  '28',
#  '68',
#  '69',
#  '70',
#  '54',
#  '41',
#  '41',
#  '69',
#  '68',
#  '11',
#  '5',
#  '7',
#  '79',
#  '80',
#  '9',
#  '82',
#  '74',
#  '70',
#  '85',
#  '86',
#  '26',
#  '74',
#  '10',
#  '40',
#  '17',
#  '74',
#  '58',
#  '79',
#  '56',
#  '96',
#  '97',
#  '98',
#  '90',
#  '80']

# %%
lastweek = soup.findAll('li', attrs={'class' : "o-chart-results-list__item // a-chart-color lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center u-hidden@mobile-max"})

# %%
lastweek
# Out:
# [<li class="o-chart-results-list__item // a-chart-color lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center u-hidden@mobile-max">
#  <span class="c-label u-font-family-secondary@mobile-max u-font-family-basic@tablet u-font-weight-800@tablet u-font-size-12 u-line-height-normal lrv-u-padding-tb-00@mobile-max u-min-width-30px u-width-auto@mobile-max u-min-width-auto@mobile-max lrv-u-margin-r-050@mobile-max">
#
#  	1
#  </span>
#  </li>,
#  <li class="o-chart-results-list__item // a-chart-color lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center u-hidden@mobile-max">
#  <span class="c-label u-font-family-secondary@mobile-max u-font-family-basic@tablet u-font-weight-800@tablet u-font-size-12 u-line-height-normal lrv-u-padding-tb-00@mobile-max u-min-width-30px u-width-auto@mobile-max u-min-width-auto@mobile-max lrv-u-margin-r-050@mobile-max">
#
#  	7
#  </span>
#  </li>,
# ...
